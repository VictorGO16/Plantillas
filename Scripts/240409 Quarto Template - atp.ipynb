# %% [markdown]
# ```{qmd}
# ---
# title: "Testeo ERCE, Agosto 2018"
# author: "Quien crea"
# date: "Fecha: 180829"
# format: html
# editor: visual
# ---
#
# # Seteo Inicial
#
# ```{{r}}
# #| code-fold: true
# rm(list=ls(all=TRUE))
# view(ls())
# cat("\014")
# ```
#
# ```{=html}
# <!--
# *****************************************************************************
#   Nombre del proyecto :   Testeo ERCE, Agosto 2018
#   Quien crea          :                      Fecha: 180829
#   Quien revisa        :                             Fecha:
#
#   Objetivos           :
#   Pasos               :
#   Productos           :
#
#   Chequeos realizados :
#
#   ****************************************************************************
# -->
# ```
#
#
# # Funciones
#
# ```{{r}}
# #| code-fold: true
# cargar <- function(package_name) {
#   if (!require(package_name, character.only = TRUE)) {
#     install.packages(package_name)
#     library(package_name, character.only = TRUE)
#   }
# }
#
# z <- function(object) {
#   view(object)
# }
#
# z(ls())
# ```
#
# # Paquetes
#
# ```{{r}}
# #| code-fold: true
# cargar("rstudioapi")
# cargar("tidyverse")
# cargar("janitor")
# cargar("openxlsx")
# ```
#
# # Ruta Dinámica y Creación de Carpetas
#
# ```{{r}}
# #| code-fold: true
# ruta_actual <- dirname(rstudioapi::getActiveDocumentContext()$path)
# setwd(ruta_actual)
# Insumos <- file.path("..", "01. Insumos//")
# Procedimientos <- file.path("..", "02. Procedimientos//")
# Productos <- file.path("..", "03. Productos//")
# ```
#
# # Inicio
#
# ```{{r}}
# #| code-fold: true
# fecha <- 190117
# fecha_imp <- 190111
# base <- "A3_1"
# ```
#
# # Registro de Log de Consola, Runner y Hora de Ejecución en .txt
#
# ```{{r}}
# #| code-fold: true
# ```
